# %%
data_panen = {
    'lokasi1': {
        'nama_lokasi': 'Kebun A',
        'hasil_panen': {
            'padi': 1200,
            'jagung': 800,
            'kedelai': 500
        }
    },
    'lokasi2': {
        'nama_lokasi': 'Kebun B',
        'hasil_panen': {
            'padi': 1500,
            'jagung': 900,
            'kedelai': 450
        }
    },
    'lokasi3': {
        'nama_lokasi': 'Kebun C',
        'hasil_panen': {
            'padi': 1100,
            'jagung': 750,
            'kedelai': 600
        }
    },
    'lokasi4': {
        'nama_lokasi': 'Kebun D',
        'hasil_panen': {
            'padi': 1300,
            'jagung': 850,
            'kedelai': 550
        }
    },
    'lokasi5': {
        'nama_lokasi': 'Kebun E',
        'hasil_panen': {
            'padi': 1400,
            'jagung': 950,
            'kedelai': 480
        }
    }
}

for lokasi, data in data_panen.items():
    print(f"Nama Lokasi: {data['nama_lokasi']}")
    print("Hasil Panen:")
    for komoditas, jumlah in data['hasil_panen'].items():
        print(f"  {komoditas}: {jumlah} kg")
    print("\n")

jagung_lokasi2 = data_panen['lokasi2']['hasil_panen']['jagung']
print(f"Jumlah hasil panen jagung dari lokasi 2: {jagung_lokasi2} kg \n")

total_padi = []
total_kedelai = []
for lokasi, data in data_panen.items():
    total_padi.append(data['hasil_panen']['padi'])
    total_kedelai.append(data['hasil_panen']['kedelai'])
print(f"Jumlah hasil panen padi dari setiap lokasi: {total_padi}")
print(f"Jumlah hasil panen kedelai dari setiap lokasi: {total_kedelai} \n")

padi_lokasi1, kedelai_lokasi1 = data_panen['lokasi1']['hasil_panen']['padi'], data_panen['lokasi1']['hasil_panen']['kedelai']
padi_lokasi2, kedelai_lokasi2 = data_panen['lokasi2']['hasil_panen']['padi'], data_panen['lokasi2']['hasil_panen']['kedelai']
padi_lokasi3, kedelai_lokasi3 = data_panen['lokasi3']['hasil_panen']['padi'], data_panen['lokasi3']['hasil_panen']['kedelai']
padi_lokasi4, kedelai_lokasi4 = data_panen['lokasi4']['hasil_panen']['padi'], data_panen['lokasi4']['hasil_panen']['kedelai']
padi_lokasi5, kedelai_lokasi5 = data_panen['lokasi5']['hasil_panen']['padi'], data_panen['lokasi5']['hasil_panen']['kedelai']
print(f"Lokasi 1 - Padi: {padi_lokasi1} kg, Kedelai: {kedelai_lokasi1} kg")
print(f"Lokasi 2 - Padi: {padi_lokasi2} kg, Kedelai: {kedelai_lokasi2} kg")
print(f"Lokasi 3 - Padi: {padi_lokasi3} kg, Kedelai: {kedelai_lokasi3} kg")
print(f"Lokasi 4 - Padi: {padi_lokasi4} kg, Kedelai: {kedelai_lokasi4} kg")
print(f"Lokasi 5 - Padi: {padi_lokasi5} kg, Kedelai: {kedelai_lokasi5} kg \n")


padi_lokasi1 = data_panen['lokasi1']['hasil_panen']['padi']
kedelai_lokasi1 = data_panen['lokasi1']['hasil_panen']['kedelai']
padi_lokasi2 = data_panen['lokasi2']['hasil_panen']['padi']
kedelai_lokasi2 = data_panen['lokasi2']['hasil_panen']['kedelai']
padi_lokasi3 = data_panen['lokasi3']['hasil_panen']['padi'] 
kedelai_lokasi3 = data_panen['lokasi3']['hasil_panen']['kedelai']
padi_lokasi4 = data_panen['lokasi4']['hasil_panen']['padi']
kedelai_lokasi4 = data_panen['lokasi4']['hasil_panen']['kedelai']
padi_lokasi5 = data_panen['lokasi5']['hasil_panen']['padi']
kedelai_lokasi5 = data_panen['lokasi5']['hasil_panen']['kedelai']
print(f"Jumlah hasil panen padi di lokasi1: {padi_lokasi1} kg, kedelai: {kedelai_lokasi1} kg")
print(f"Jumlah hasil panen padi di lokasi2: {padi_lokasi2} kg, kedelai: {kedelai_lokasi2} kg")
print(f"Jumlah hasil panen padi di lokasi3: {padi_lokasi3} kg, kedelai: {kedelai_lokasi3} kg")
print(f"Jumlah hasil panen padi di lokasi4: {padi_lokasi4} kg, kedelai: {kedelai_lokasi4} kg")
print(f"Jumlah hasil panen padi di lokasi5: {padi_lokasi5} kg, kedelai: {kedelai_lokasi5} kg \n")

for lokasi, data in data_panen.items():
    padi = data['hasil_panen']['padi']
    jagung = data['hasil_panen']['jagung']
    if padi > 1300 or jagung > 800:
        print(f"Lokasi {data['nama_lokasi']} memerlukan perhatian khusus.")
    else:
        print(f"Lokasi {data['nama_lokasi']} dalam kondisi baik.")
# Out:
# Nama Lokasi: Kebun A
# Hasil Panen:
#   padi: 1200 kg
#   jagung: 800 kg
#   kedelai: 500 kg
#
#
# Nama Lokasi: Kebun B
# Hasil Panen:
#   padi: 1500 kg
#   jagung: 900 kg
#   kedelai: 450 kg
#
#
# Nama Lokasi: Kebun C
# Hasil Panen:
#   padi: 1100 kg
#   jagung: 750 kg
#   kedelai: 600 kg
#
#
# Nama Lokasi: Kebun D
# Hasil Panen:
#   padi: 1300 kg
#   jagung: 850 kg
#   kedelai: 550 kg
#
#
# Nama Lokasi: Kebun E
# Hasil Panen:
#   padi: 1400 kg
#   jagung: 950 kg
#   kedelai: 480 kg
#
#
# Jumlah hasil panen jagung dari lokasi 2: 900 kg
#
# Jumlah hasil panen padi dari setiap lokasi: [1200, 1500, 1100, 1300, 1400]
# Jumlah hasil panen kedelai dari setiap lokasi: [500, 450, 600, 550, 480]
#
# Lokasi 1 - Padi: 1200 kg, Kedelai: 500 kg
# Lokasi 2 - Padi: 1500 kg, Kedelai: 450 kg
# Lokasi 3 - Padi: 1100 kg, Kedelai: 600 kg
# Lokasi 4 - Padi: 1300 kg, Kedelai: 550 kg
# Lokasi 5 - Padi: 1400 kg, Kedelai: 480 kg
# Jumlah hasil panen padi di lokasi1: 1200 kg, kedelai: 500 kg
# ...
